# %% [markdown]
# ### 增强图片对比度

# %%
from PIL import Image
from PIL import ImageEnhance
 
img = Image.open('./Test_428.png')
img.show()
 
#对比度增强  
enh_con = ImageEnhance.Contrast(img)  
contrast = 1000
img_contrasted = enh_con.enhance(contrast)  
img_contrasted.show() 
img_contrasted.save("./test3.png")

# %%
import cv2  
import numpy

# %% [markdown]
# ### 计算轮廓面积

# %%
def areaCal(contour):

    area = 0
    for i in range(len(contour)):
        area += cv2.contourArea(contour[i])

    return area

# %% [markdown]
# ### 导入增强对比度后的图片、提取R层、找出轮廓

# %%
img_path = r'./test1.png'
img = cv2.imread(img_path)
red = img[:, :, 2]
ret, binary = cv2.threshold(red, 50, 255, cv2.THRESH_BINARY)
contours, hierarchy = cv2.findContours(binary, cv2.RETR_TREE, 
                                       cv2.CHAIN_APPROX_SIMPLE)
print('面积为：', areaCal(contours))
# Out:
# 面积为： 1704.5

# %% [markdown]
# ### 通过循环找出最适合的阈值

# %%
    ret, binary = cv2.threshold(red, i, 255, cv2.THRESH_BINARY)
    contours, hierarchy = cv2.findContours(binary, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    print(i, ':', areaCal(contours))
# Out:
# 0 : 1732.0
# 1 : 1732.0
# 2 : 1732.0
# 3 : 1732.0
# 4 : 1732.0
# 5 : 1732.0
# 6 : 1732.0
# 7 : 1732.0
# 8 : 1732.0
# 9 : 1732.0
# 10 : 1732.0
# 11 : 1732.0
# 12 : 1732.0
# 13 : 1732.0
# 14 : 1732.0
# 15 : 1732.0
# 16 : 1732.0
# 17 : 1732.0
# 18 : 1732.0
# 19 : 1732.0
# 20 : 1732.0
# 21 : 1732.0
# 22 : 1732.0
# 23 : 1732.0
# 24 : 1732.0
# 25 : 1732.0
# 26 : 1732.0
# 27 : 1732.0
# 28 : 1732.0
# 29 : 1732.0
# 30 : 1732.0
# 31 : 1732.0
# 32 : 1732.0
# 33 : 1732.0
# 34 : 1732.0
# 35 : 1732.0
# 36 : 1732.0
# 37 : 1732.0
# 38 : 1732.0
# 39 : 1704.5
# 40 : 1704.5
# 41 : 1704.5
# 42 : 1704.5
# 43 : 1704.5
# 44 : 1704.5
# 45 : 1704.5
# 46 : 1704.5
# 47 : 1704.5
# 48 : 1704.5
# 49 : 1704.5
# 50 : 1704.5
# 51 : 1704.5
# 52 : 1704.5
# 53 : 1704.5
# 54 : 1704.5
# 55 : 1704.5
# 56 : 1704.5
# 57 : 1704.5
# 58 : 1704.5
# 59 : 1704.5
# 60 : 1704.5
# 61 : 1704.5
# 62 : 1704.5
# 63 : 1704.5
# 64 : 1704.5
# 65 : 1704.5
# 66 : 1704.5
# 67 : 1704.5
# 68 : 1704.5
# 69 : 1704.5
# 70 : 1704.5
# 71 : 1704.5
# ...

# %% [markdown]
# ### 找出轮廓后在原图上进行标注

# %%
temp = cv2.imread('./test.png')
cv2.drawContours(temp, contours, -1, (0,0,255),3, 1)
cv2.imshow('img', temp)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2  
import numpy
img_path = r'./Test_428.png'
img = cv2.imread(img_path)
red = img[:, :, 2]
cv2.imshow('img', red)
cv2.waitKey(0)
cv2.destroyAllWindows()
